# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 15px; height: 80px">
#
# # Project 3
#
# ### Regression and Classification with the Ames Housing Data
#
# ---
#
# You have just joined a new "full stack" real estate company in Ames, Iowa. The strategy of the firm is two-fold:
# - Own the entire process from the purchase of the land all the way to sale of the house, and anything in between.
# - Use statistical analysis to optimize investment and maximize return.
#
# The company is still small, and though investment is substantial the short-term goals of the company are more oriented towards purchasing existing houses and flipping them as opposed to constructing entirely new houses. That being said, the company has access to a large construction workforce operating at rock-bottom prices.
#
# This project uses the [Ames housing data recently made available on kaggle](https://www.kaggle.com/c/house-prices-advanced-regression-techniques).

# %%
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from pprint import pprint

sns.set_style('whitegrid')

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

import imp
Project_03_Helper = imp.load_source('Project_03_Helper', './Project_03_Helper.py')
from Project_03_Helper import Project_03_Helper

helper = Project_03_Helper()

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 1. Estimating the value of homes from fixed characteristics.
#
# ---
#
# Your superiors have outlined this year's strategy for the company:
# 1. Develop an algorithm to reliably estimate the value of residential houses based on *fixed* characteristics.
# 2. Identify characteristics of houses that the company can cost-effectively change/renovate with their construction team.
# 3. Evaluate the mean dollar value of different renovations.
#
# Then we can use that to buy houses that are likely to sell for more than the cost of the purchase plus renovations.
#
# Your first job is to tackle #1. You have a dataset of housing sale data with a huge amount of features identifying different aspects of the house. The full description of the data features can be found in a separate file:
#
#     housing.csv
#     data_description.txt
#
# You need to build a reliable estimator for the price of the house given characteristics of the house that cannot be renovated. Some examples include:
# - The neighborhood
# - Square feet
# - Bedrooms, bathrooms
# - Basement and garage space
#
# and many more.
#
# Some examples of things that **ARE renovate-able:**
# - Roof and exterior features
# - "Quality" metrics, such as kitchen quality
# - "Condition" metrics, such as condition of garage
# - Heating and electrical components
#
# and generally anything you deem can be modified without having to undergo major construction on the house.
#
# ---
#
# **Your goals:**
# 1. Perform any cleaning, feature engineering, and EDA you deem necessary.
# - Be sure to remove any houses that are not residential from the dataset.
# - Identify **fixed** features that can predict price.
# - Train a model on pre-2010 data and evaluate its performance on the 2010 houses.
# - Characterize your model. How well does it perform? What are the best estimates of price?
#
# > **Note:** The EDA and feature engineering component to this project is not trivial! Be sure to always think critically and creatively. Justify your actions! Use the data description file!

# %%
# Load the data
house = pd.read_csv('./housing.csv')

# %% [markdown]
# <img src="https://png.icons8.com/color/50/000000/home.png" style="float: left; margin: 25px 15px 15px 15px; height: 30px">
# <font color="DarkSlateBlue">
# ###  Structure of Answer to Qn 1
# <br>
# - [Preprocess Data](#preprocess_data)
#     - [Drop Non-Residential Data](#drop_nonresidential)
#     - [Check target column](#check_target)
#     - [Split into training and test sets](#split_train_test)
#     - [Training set: Check and Handle null values](#check_nulls_train)
#     - [Drop any obviously irrelevant features](#drop_obvious)
#     - [Preprocess all other continuous features](#preprocess_numerical)
#     - [Preprocess all other categorical features](#preprocess_categorical)
# - [Prepare train and test set](#prepare_train_test)
#
# - [Review of the Least Squares Loss Function for Regression](#lsq-loss)
#     - [Exercise 1: Code the Loss Function](#exercise-1)
# - [Partial Derivatives of the Loss Function](#partial-derivatives)
#     - [Partial Derivative With Respect to $\beta_0$](#beta0)
#     - [Partial Derivative With Respect to $\beta_1$](#beta1)
#     - [Exercise 2: Code the Partial Derivative Functions](#exercise-2)
#     - [Iterating Toward the Minimum](#iterating)

# %% [markdown]
# <a id='preprocess_data'></a>
# ## Preprocess data

# %%
# Check info e.g. data dimensions, data types and number of non-nulls
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
FIXED_FEATURES =  ['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea','Street','Alley','LotShape', 'LandContour','Utilities','LotConfig','LandSlope','Neighborhood','Condition1','Condition2','BldgType','HouseStyle','YearBuilt','Foundation','BsmtQual','BsmtExposure','BsmtFinType1','TotalBsmtSF','1stFlrSF','2ndFlrSF','BsmtFullBath','BsmtHalfBath','FullBath','HalfBath','BedroomAbvGr','KitchenAbvGr','TotRmsAbvGrd','Fireplaces','GarageType',	 'GarageYrBlt','GarageCars','GarageArea','PoolArea','MiscFeature','MiscVal','MoSold','YrSold','SaleType','SaleCondition']
pprint(FIXED_FEATURES)
RENOVATABLE_FEATURES = [x for x in list(house.columns.values) if x not in FIXED_FEATURES]
# Out:
# ['MSSubClass',
#  'MSZoning',
#  'LotFrontage',
#  'LotArea',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'YearBuilt',
#  'Foundation',
#  'BsmtQual',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'PoolArea',
#  'MiscFeature',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SaleType',
#  'SaleCondition']

# %%
pprint(RENOVATABLE_FEATURES)
# Out:
# ['Id',
#  'OverallQual',
#  'OverallCond',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'BsmtCond',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'LowQualFinSF',
#  'GrLivArea',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolQC',
#  'Fence',
#  'SalePrice']

# %%
# Take a look at some samples
samples_indices = house.sample(10).index.tolist()
house.iloc[samples_indices,0:20]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 47      48          20       FV         84.0    11096   Pave   NaN      Reg
# 432    433         160       RM         24.0     1920   Pave   NaN      Reg
# 581    582          20       RL         98.0    12704   Pave   NaN      Reg
# 715    716          20       RL         78.0    10140   Pave   NaN      Reg
# 904    905          20       RL          NaN     6173   Pave   NaN      IR1
# 1427  1428          50       RL         60.0    10930   Pave  Grvl      Reg
# 1098  1099          50       RM         50.0     6000   Pave   NaN      Reg
# 850    851         120       RM         36.0     4435   Pave   NaN      Reg
# 1251  1252         120       RL          NaN     3136   Pave   NaN      IR1
# 956    957         160       RM         24.0     1300   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
house.iloc[samples_indices,21:40]
# Out:
#      RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea  \
# 47       Gable  CompShg     VinylSd     VinylSd       None         0.0
# 432      Gable  CompShg     HdBoard     HdBoard    BrkFace       376.0
# 581        Hip  CompShg     VinylSd     VinylSd    BrkFace       306.0
# 715        Hip  CompShg     HdBoard     HdBoard    BrkFace       174.0
# 904      Gable  CompShg     HdBoard     Wd Sdng    BrkFace        75.0
# 1427     Gable  CompShg     MetalSd     MetalSd       None         0.0
# 1098     Gable  CompShg     MetalSd     MetalSd       None         0.0
# 850      Gable  CompShg     VinylSd     VinylSd    BrkFace       170.0
# 1251     Gable  CompShg     VinylSd     Wd Shng      Stone       163.0
# 956      Gable  CompShg     MetalSd     MetalSd       None         0.0
#
#      ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 47          Gd        TA      PConc       Gd       TA           Av
# ...

# %%
house.iloc[samples_indices,41:60]
# Out:
#      CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  \
# 47            Y      SBrkr      1656         0             0       1656
# 432           Y      SBrkr       765       600             0       1365
# 581           Y      SBrkr      2042         0             0       2042
# 715           Y      SBrkr      1350         0             0       1350
# 904           Y      SBrkr       902         0             0        902
# 1427          Y      FuseA      1048       510             0       1558
# 1098          Y      SBrkr       757       567             0       1324
# 850           Y      SBrkr       848         0             0        848
# 1251          Y      SBrkr      1405         0             0       1405
# 956           Y      SBrkr       561       668             0       1229
#
#       BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 47               0             0         2         0             3
# ...

# %%
house.iloc[samples_indices,61:81]
# Out:
#       GarageCars  GarageArea GarageQual GarageCond PavedDrive  WoodDeckSF  \
# 47             3         826         TA         TA          Y           0
# 432            2         440         TA         TA          Y         240
# 581            3        1390         TA         TA          Y           0
# 715            2         478         TA         TA          Y           0
# 904            1         288         TA         TA          Y           0
# 1427           1         288         TA         TA          Y           0
# 1098           1         240         TA         TA          Y           0
# 850            2         420         TA         TA          Y         140
# 1251           2         478         TA         TA          Y         148
# 956            2         462         TA         TA          Y         150
#
#       OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea PoolQC  \
# 47            146              0          0            0         0    NaN
# ...

# %%
# identify which features are fixed , which are variable

# %% [markdown]
# <a id='drop_nonresidential'></a>
# ### Drop data that is non-Residential

# %%
# Check any null values for MSZoning
house['MSZoning'].isnull().sum()
# Out:
# 0

# %%
house['MSZoning'].value_counts()
# Out:
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64

# %%
# check # rows left once non-Residential rows are dropped
house[house['MSZoning'].isin(['RH','RL','RP','RM'])].shape
# Out:
# (1385, 81)

# %%
# drop non-Residential rows
house = house[house['MSZoning'].isin(['RH','RL','RP','RM'])].reset_index()

# %% [markdown]
# <a id='split_train_test'></a>
# ### Split into training and test set

# %%
print(house['YrSold'].max(),house['YrSold'].min())
# Out:
# 2010 2006

# %%
# Instructions are to Train a model on pre-2010 data and evaluate its performance on the 2010 houses.
#house['YearBuilt'].hist( bins= int(round( (house['YearBuilt'].max()-house['YearBuilt'].min() ) / 10)))                       
sns.distplot(house['YrSold'],bins= 8)

# %%
sns.violinplot(house['YearBuilt'])

# %%
# split and validate the number of rows
house_train = house[house['YrSold'] < 2010].reset_index(drop=True)
house_test = house[~house.index.isin(house_train.index)].reset_index(drop=True)
print(house_train.shape)
print(house_test.shape)
# Out:
# (1221, 82)
# (164, 82)

# %% [markdown]
# <a id='check_target'></a>
# ### Check target value column

# %%
house_train[['SalePrice']].boxplot()
# some outliers

# %%
sns.violinplot(x=house_train['SalePrice'])

# %% [markdown]
# <a id='check_nulls_train'></a>
# ### Training Set : Check and handle null values

# %%
# fish out the nulls
null_features_df = helper.find_nulls(house_train)
null_features_df
# Out:
#               number of nulls object type
# PoolQC                   1214      object
# MiscFeature              1182      object
# Alley                    1160      object
# Fence                     983      object
# FireplaceQu               557      object
# LotFrontage               222     float64
# GarageType                 68      object
# GarageYrBlt                68     float64
# GarageFinish               68      object
# GarageQual                 68      object
# GarageCond                 68      object
# BsmtExposure               33      object
# BsmtFinType2               33      object
# BsmtFinType1               32      object
# BsmtCond                   32      object
# BsmtQual                   32      object
# MasVnrArea                  4     float64
# MasVnrType                  4      object
# Electrical                  1      object

# %%
print(house_train['PoolQC'].value_counts()/house.shape[0]*100)
# There are only values for less than 1 % of the data; won't do much as a feature, should drop it but 
# just want to confirm Feature Selection techniques should sieve it out
# So, decide to retain first and convert to dummies
helper.add_feature_to_make_dummy('PoolQC',drop_first=False)
# Out:
# Gd    0.216606
# Fa    0.144404
# Ex    0.144404
# Name: PoolQC, dtype: float64

# %%
# Check Pool Area at the same time
print(house_train['PoolArea'].value_counts()/house_train.shape[0]*100)

# check how price is correlated with PoolArea
sns.lmplot(x='PoolArea', y='SalePrice', data=house_train)
# No correlation can be seen, should drop 'PoolArea', but the Feature Selection should filter this out, so leave it first

# need to impute Pool Area where there are zeroes?  Not important for now as likely will be sieved out
# Out:
# 0      99.426699
# 738     0.081900
# 648     0.081900
# 576     0.081900
# 555     0.081900
# 519     0.081900
# 512     0.081900
# 480     0.081900
# Name: PoolArea, dtype: float64

# %%
print(house_train['Alley'].value_counts()/house_train.shape[0]*100)
# The null values for Alley represent no alley access, should drop this 

# just want to confirm Feature Selection techniques should filter it out
# So, convert to dummies first
helper.add_feature_to_make_dummy('Alley',drop_first=False)
# Out:
# Grvl    3.849304
# Pave    1.146601
# Name: Alley, dtype: float64

# %%
house_train['MiscFeature'].value_counts()/house_train.shape[0]*100
# The null values for 'MiscFeature' means no extra features. Only less than 4% of 'MiscFeature' has any values.
# Out:
# Shed    2.866503
# Gar2    0.163800
# TenC    0.081900
# Othr    0.081900
# Name: MiscFeature, dtype: float64

# %%
# Is 4% signficant?  Let's check plot against SalePrice
sns.catplot(x='MiscFeature', y='SalePrice', data=house_train)
sns.catplot(x='MiscFeature', y='SalePrice', data=house_train, kind='bar')
sns.catplot(x='MiscFeature', y='SalePrice', data=house_train, kind='violin')

# Seems to have some effect, not sure how, let's convert this column to dummies first and see how Feature Selection 
# will treat this 
helper.add_feature_to_make_dummy('MiscFeature',drop_first=False)

# %%
house_train['Fence'].value_counts()/house_train.shape[0]*100
# The null values for Fence represent 'no fence', hence are meaningful and can be used as reference column later.

helper.add_feature_to_make_dummy('Fence',drop_first=False)

# %%
print(house_train['FireplaceQu'].value_counts())
helper.add_feature_to_make_dummy('FireplaceQu',drop_first=False)
# Out:
# Gd    330
# TA    269
# Fa     27
# Ex     21
# Po     17
# Name: FireplaceQu, dtype: int64

# %%
house_train['LotFrontage'].describe()
house_train['LotFrontage'].hist(bins=20)
# distribution of 'LotFrontage' looks ok

print(house_train['LotFrontage'].isnull().sum()/house_train.shape[0])
# Out:
# 0.18181818181818182

# %%
house_train.boxplot('LotFrontage')
# 'LotFrontage' does not have many null values

# %%
# Let's impute 'LotFrontage' with median
helper.add_feature_to_impute_with_median('LotFrontage',house_train)

# %%
'''
Null Values
======================
GarageType	79	object
GarageYrBlt	79	float64
GarageFinish	79	object
GarageQual	79	object
GarageCond	79	object

		
GarageType: Garage location
		
       2Types	More than one type of garage
       Attchd	Attached to home
       Basment	Basement Garage
       BuiltIn	Built-In (Garage part of house - typically has room above garage)
       CarPort	Car Port
       Detchd	Detached from home
       NA	No Garage
		
GarageYrBlt: Year garage was built
		
GarageFinish: Interior finish of the garage

       Fin	Finished
       RFn	Rough Finished	
       Unf	Unfinished
       NA	No Garage
		
GarageCars: Size of garage in car capacity

GarageArea: Size of garage in square feet

GarageQual: Garage quality

       Ex	Excellent
       Gd	Good
       TA	Typical/Average
       Fa	Fair
       Po	Poor
       NA	No Garage
		
GarageCond: Garage condition

       Ex	Excellent
       Gd	Good
       TA	Typical/Average
       Fa	Fair
       Po	Poor
       NA	No Garage
		
'''
# Out:
# '\nNull Values\n======================\nGarageType\t79\tobject\nGarageYrBlt\t79\tfloat64\nGarageFinish\t79\tobject\nGarageQual\t79\tobject\nGarageCond\t79\tobject\n\n\t\t\nGarageType: Garage location\n\t\t\n       2Types\tMore than one type of garage\n       Attchd\tAttached to home\n       Basment\tBasement Garage\n       BuiltIn\tBuilt-In (Garage part of house - typically has room above garage)\n       CarPort\tCar Port\n       Detchd\tDetached from home\n       NA\tNo Garage\n\t\t\nGarageYrBlt: Year garage was built\n\t\t\nGarageFinish: Interior finish of the garage\n\n       Fin\tFinished\n       RFn\tRough Finished\t\n       Unf\tUnfinished\n       NA\tNo Garage\n\t\t\nGarageCars: Size of garage in car capacity\n\nGarageArea: Size of garage in square feet\n\nGarageQual: Garage quality\n\n       Ex\tExcellent\n       Gd\tGood\n       TA\tTypical/Average\n       Fa\tFair\n       Po\tPoor\n       NA\tNo Garage\n\t\t\nGarageCond: Garage condition\n\n       Ex\tExcellent\n       Gd\t
# ...

# %%
print(house_train['GarageType'].value_counts()/house_train.shape[0]*100)
# The null values for 'GarageType' means no garage, which is meaningful.
# Out:
# Attchd     59.459459
# Detchd     26.617527
# BuiltIn     6.142506
# Basment     1.146601
# CarPort     0.573301
# 2Types      0.491400
# Name: GarageType, dtype: float64

# %%
sns.catplot(x='GarageType', y='SalePrice', data=house_train)
sns.catplot(x='GarageType', y='SalePrice', data=house_train, kind='bar')

# %%
# double check the other Garage features to make sure everything makes sense when 'GarageType' is null
house_train[house_train['GarageType'].isnull()][['GarageYrBlt','GarageFinish','GarageCars','GarageArea','GarageQual','GarageCond']].isnull().sum()
# looks ok
# Out:
# GarageYrBlt     68
# GarageFinish    68
# GarageCars       0
# GarageArea       0
# GarageQual      68
# GarageCond      68
# dtype: int64

# %%
# For numerical columns 'GarageCars' and 'GarageArea', the values are zero when there is no garage. 
# Check out the plots, such zero values may skew the plot against SalePrice
sns.pairplot(x_vars=['GarageCars','GarageArea'], y_vars=['SalePrice'], data=house_train, hue='GarageType')
#  the zero values doesn't seem signficant in skewing correlation with SalePrice if any

# check only those with null 'GarageType' has GarageCars and GarageArea set to 0
house_train[(house_train['GarageCars']==0) | (house_train['GarageArea']==0)].shape
# Out:
# (68, 82)

# %%
# still as a matter of principal, set these numerical colums to the median in order not to skew linear correlation if any
helper.add_feature_to_impute_with_median('GarageCars',house_train,0)
helper.add_feature_to_impute_with_median('GarageArea',house_train,0)
helper.add_feature_to_impute_with_median('GarageYrBlt',house_train)

# %%
print(house_train['GarageYrBlt'].describe())
sns.violinplot(house_train['GarageYrBlt'])
# seem to look ok
# Out:
# count    1153.000000
# mean     1977.314831
# std        24.732435
# min      1906.000000
# 25%      1960.000000
# 50%      1978.000000
# 75%      2001.000000
# max      2009.000000
# Name: GarageYrBlt, dtype: float64

# %%
# for 'GarageYrBlt' check out its effect on SalePrice, vs 'GarageFinish'
sns.lmplot(x='GarageYrBlt',y='SalePrice',data=house_train,hue='GarageFinish')
# looks like there is a relationship with SalePrice; the relationship between GarageFinish and SalePrice looks even stronger

# %%
house['GarageFinish'].value_counts()
# Out:
# Unf    585
# RFn    389
# Fin    332
# Name: GarageFinish, dtype: int64

# %%
sns.catplot(x='GarageFinish', y='SalePrice', data=house_train)

# %%
sns.catplot(x='GarageQual', y='SalePrice', data=house_train)
sns.catplot(x='GarageCond', y='SalePrice', data=house_train, kind='bar')

# %%
sns.catplot(x='GarageCond', y='SalePrice', data=house_train)
sns.catplot(x='GarageCond', y='SalePrice', data=house_train, kind='bar')

# %%
# Finally, let's convert the categorical Garage values to dummies
helper.add_feature_to_make_dummy(['GarageType','GarageFinish','GarageQual','GarageCond'],drop_first=False)

# %% [markdown]
# Null values:
#
#     BsmtExposure	38	object
#     BsmtFinType2	38	object
#     BsmtFinType1	37	object
#     BsmtCond	37	object
#     BsmtQual	37	object
#
# BsmtQual: Evaluates the height of the basement
#
#        Ex	Excellent (100+ inches)
#        Gd	Good (90-99 inches)
#        TA	Typical (80-89 inches)
#        Fa	Fair (70-79 inches)
#        Po	Poor (<70 inches
#        NA	No Basement
#
# BsmtCond: Evaluates the general condition of the basement
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical - slight dampness allowed
#        Fa	Fair - dampness or some cracking or settling
#        Po	Poor - Severe cracking, settling, or wetness
#        NA	No Basement
#
# BsmtExposure: Refers to walkout or garden level walls
#
#        Gd	Good Exposure
#        Av	Average Exposure (split levels or foyers typically score average or above)
#        Mn	Mimimum Exposure
#        No	No Exposure
#        NA	No Basement
#
# BsmtFinType1: Rating of basement finished area
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement
#
# BsmtFinSF1: Type 1 finished square feet
#
# BsmtFinType2: Rating of basement finished area (if multiple types)
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement
#
# BsmtFinSF2: Type 2 finished square feet
#
# BsmtUnfSF: Unfinished square feet of basement area
#
# TotalBsmtSF: Total square'feet of basement area

# %%
# double check the other Basement features to make sure everything makes sense when 'BsmtCond' is null
house_train[house_train['BsmtQual'].isnull()][['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinSF1','BsmtFinType2','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF']].isnull().sum()
# looks ok
# Out:
# BsmtQual        32
# BsmtCond        32
# BsmtExposure    32
# BsmtFinType1    32
# BsmtFinSF1       0
# BsmtFinType2    32
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# dtype: int64

# %%
# BsmtExposure and BsmtFinType2 has 1 more null than the others, let's investigate more
house_train[(house_train['BsmtExposure'].isnull() | house_train['BsmtFinType2'].isnull()) & house_train['BsmtQual'].notnull()][['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinSF1','BsmtFinType2','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF']]
# Out:
#     BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  \
# 267       Gd       TA           No          GLQ        1124          NaN
# 787       Gd       TA          NaN          Unf           0          Unf
#
#      BsmtFinSF2  BsmtUnfSF  TotalBsmtSF
# 267         479       1603         3206
# 787           0        936          936

# %%
# Only 1 such BsmtFinSF2 that is null while FinSF2 values are present, since there is non-zero BsmtUnfSF, will fill as 'Unf'
house_train.loc[267,'BsmtFinType2'] = 'Unf'

# %%
# For numerical Basement columns, the values are zero when there is no basement. 
# Check out the plots, such zero values may skew the plot against SalePrice
sns.violinplot(data=house[['BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF']])
sns.pairplot(x_vars=['BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF'], y_vars=['SalePrice'], data=house, hue='BsmtQual')
#  Seems quite a significant number of zeros, later need to impute the zero values to median !

# %%
# Set the numerical values to median so as not to skew any linear correlation with target if any
helper.add_feature_to_impute_with_median(['BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF'],house_train,missing_values=0)

# %%
# create dummies for the Basement categorical values
helper.add_feature_to_make_dummy(['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2'],drop_first=False)

# %%
'''
Null Values
======================
MasVnrArea	5	float64
MasVnrType	5	object
Electrical	1	object

MasVnrType: Masonry veneer type

       BrkCmn	Brick Common
       BrkFace	Brick Face
       CBlock	Cinder Block
       None	None
       Stone	Stone
	
MasVnrArea: Masonry veneer area in square feet
'''
# Out:
# '\nNull Values\n======================\nMasVnrArea\t5\tfloat64\nMasVnrType\t5\tobject\nElectrical\t1\tobject\n\nMasVnrType: Masonry veneer type\n\n       BrkCmn\tBrick Common\n       BrkFace\tBrick Face\n       CBlock\tCinder Block\n       None\tNone\n       Stone\tStone\n\t\nMasVnrArea: Masonry veneer area in square feet\n'

# %%
house_train[house_train['MasVnrType'].isnull()][['MasVnrArea','MasVnrType']]
# Out:
#       MasVnrArea MasVnrType
# 438          NaN        NaN
# 776          NaN        NaN
# 1041         NaN        NaN
# 1070         NaN        NaN

# %%
house_train['MasVnrType'].value_counts()
# most houses do not have Masonry veneer
# Out:
# None       720
# BrkFace    380
# Stone      103
# BrkCmn      14
# Name: MasVnrType, dtype: int64

# %%
house_train['MasVnrArea'].hist(bins=20)
# most of the values are zero as most do not have Masonry veneer

# %%
# check the relationship with SalePrice
sns.regplot(house_train['MasVnrArea'],house_train['SalePrice'])

# %%
# let's only consider values > 0, just curious to explore what happens if we use log
house_train[house_train['MasVnrArea']>0]['MasVnrArea'].apply(np.log).hist(bins=50)

# %%
# check the log relationship with SalePrice, 
house_with_MasVnr = house_train[house_train['MasVnrArea']>0]
sns.regplot(x=np.log(house_with_MasVnr['MasVnrArea']), y=house_with_MasVnr['SalePrice'])
# looks like there is a relationship with SalePrice;

# %%
print(np.corrcoef(x=np.log(house_with_MasVnr['MasVnrArea']), y=house_with_MasVnr['SalePrice']))
print(np.corrcoef(x=house_with_MasVnr['MasVnrArea'], y=house_with_MasVnr['SalePrice']))
# looks like the correlation is not that great.  Logging doesn't really help, haha

# still, let's impute the MasVnrArea, i.e. replace 0 with median
helper.add_feature_to_impute_with_median('MasVnrArea',house_train)
helper.add_feature_to_make_dummy('MasVnrType', drop_first=False)
# Out:
# [[1.         0.37893545]
#  [0.37893545 1.        ]]
# [[1.         0.48157061]
#  [0.48157061 1.        ]]

# %%
'''
NULL Values
===========
Electrical	1	object

Electrical: Electrical system

       SBrkr	Standard Circuit Breakers & Romex
       FuseA	Fuse Box over 60 AMP and all Romex wiring (Average)	
       FuseF	60 AMP Fuse Box and mostly Romex wiring (Fair)
       FuseP	60 AMP Fuse Box and mostly knob & tube wiring (poor)
       Mix	Mixed
'''
# Out:
# '\nNULL Values\n===========\nElectrical\t1\tobject\n\nElectrical: Electrical system\n\n       SBrkr\tStandard Circuit Breakers & Romex\n       FuseA\tFuse Box over 60 AMP and all Romex wiring (Average)\t\n       FuseF\t60 AMP Fuse Box and mostly Romex wiring (Fair)\n       FuseP\t60 AMP Fuse Box and mostly knob & tube wiring (poor)\n       Mix\tMixed\n'

# %%
house_train[house_train['Electrical'].isnull()]
# Out:
#       index    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 1154   1379  1380          80       RL         73.0     9735   Pave   NaN
#
#      LotShape LandContour    ...     PoolArea PoolQC Fence MiscFeature  \
# 1154      Reg         Lvl    ...            0    NaN   NaN         NaN
#
#      MiscVal MoSold YrSold SaleType  SaleCondition  SalePrice
# 1154       0      5   2008       WD         Normal     167500
#
# [1 rows x 82 columns]

# %%
# Only 1 row with null, let's impute with most common frequent value
house_train['Electrical'].value_counts()
# Out:
# SBrkr    1108
# FuseA      83
# FuseF      25
# FuseP       3
# Mix         1
# Name: Electrical, dtype: int64

# %%
# fill null Electrical with most frequent value
helper.add_feature_to_impute('Electrical',fill_value='SBrkr')
helper.add_feature_to_make_dummy('Electrical',drop_first=True)

# %%
# make a list of all the features we have handled as we are handling nulls
handled_features = list(null_features_df.index)
handled_features.extend(['GarageArea','GarageCars','GarageQual','BsmtFinSF1', 'BsmtFinSF2','BsmtUnfSF','TotalBsmtSF'])

# %% [markdown]
# <a id='drop_obvious'></a>
# ### Drop any obviously irrelevant features

# %%
# drop ID as this is just a running sequence
helper.add_feature_to_drop(['Id', 'SalePrice'])
handled_features.extend(['Id','SalePrice'])

# %% [markdown]
# <a id='preprocess_numerical'></a>
# ### Process all other continuous features

# %%
# collect all numerical features
x = list(house_train.select_dtypes(include=[np.number], exclude=None).columns.values)
x.remove('index')

# take away those handled
numerical_features_to_handle = [item for item in x if item not in handled_features]

# %%
# check if any numerical values has 0 that may need to be imputed
for f in numerical_features_to_handle:
    if (house_train[f]==0).any():
        print(f)
        # Just replace zeroes with median
        helper.add_feature_to_impute_with_median(f,house_train,missing_values=0)
# Out:
# 2ndFlrSF
# LowQualFinSF
# BsmtFullBath
# BsmtHalfBath
# FullBath
# HalfBath
# BedroomAbvGr
# KitchenAbvGr
# Fireplaces
# WoodDeckSF
# OpenPorchSF
# EnclosedPorch
# 3SsnPorch
# ScreenPorch
# PoolArea
# MiscVal

# %% [markdown]
# <a id='preprocess_categorical'></a>
# ### Process all other categorical features

# %%
# collect all categorical features
x = list(house_train.select_dtypes(include=[object]).columns.values)

# take away those handled
categorical_features_to_handle = [item for item in x if item not in handled_features]

# %%
# Just make dummies but drop first column
helper.add_feature_to_make_dummy(categorical_features_to_handle,drop_first=True)

# %% [markdown]
# <a id='prepare_train_test'></a>
# ### Prepare train and test set

# %%
print(helper)
# Out:
# Features to Drop:
# ['Id', 'SalePrice']
#
# Features to Impute:
# Feature LotFrontage : Fill None with 69.0.
# Feature GarageCars : Fill 0 with 2.0.
# Feature GarageArea : Fill 0 with 472.0.
# Feature GarageYrBlt : Fill None with 1978.0.
# Feature BsmtFinSF1 : Fill 0 with 385.0.
# Feature BsmtFinSF2 : Fill 0 with 0.0.
# Feature BsmtUnfSF : Fill 0 with 476.0.
# Feature TotalBsmtSF : Fill 0 with 990.0.
# Feature MasVnrArea : Fill None with 0.0.
# Feature Electrical : Fill None with SBrkr.
# Feature 2ndFlrSF : Fill 0 with 0.0.
# Feature LowQualFinSF : Fill 0 with 0.0.
# Feature BsmtFullBath : Fill 0 with 0.0.
# Feature BsmtHalfBath : Fill 0 with 0.0.
# Feature FullBath : Fill 0 with 2.0.
# Feature HalfBath : Fill 0 with 0.0.
# Feature BedroomAbvGr : Fill 0 with 3.0.
# Feature KitchenAbvGr : Fill 0 with 1.0.
# Feature Fireplaces : Fill 0 with 1.0.
# Feature WoodDeckSF : Fill 0 with 0.0.
# Feature OpenPorchSF : Fill 0 with 24.0.
# Feature EnclosedPorch : Fill 0 with 0.0.
# ...

# %%
# Must transform on original set then split into train and test
# to ensure pd.getdummies 
# generate the same columns for both train and test sets, as
# this action is dependent on the data in that dataframe
X_f = house[FIXED_FEATURES].reindex()

# do the data preprocessing
X_f = helper.transform(X_f)
print(helper)

# split into train and test set
X_f_train = X_f[X_f['YrSold'] < 2010]
X_f_test = X_f[X_f['YrSold'] == 2010]

print(house.shape)
print(X_f_train.shape)
print(X_f_test.shape)

y_train = house[house['YrSold'] < 2010]['SalePrice']
y_test = house[house['YrSold'] == 2010]['SalePrice']

(y_test.index.values == X_f_test.index.values).all()

X_f.dtypes
# Out:
# Features to Drop:
# ['Id', 'SalePrice']
#
# Features to Impute:
# Feature LotFrontage : Fill None with 69.0.
# Feature GarageCars : Fill 0 with 2.0.
# Feature GarageArea : Fill 0 with 472.0.
# Feature GarageYrBlt : Fill None with 1978.0.
# Feature BsmtFinSF1 : Fill 0 with 385.0.
# Feature BsmtFinSF2 : Fill 0 with 0.0.
# Feature BsmtUnfSF : Fill 0 with 476.0.
# Feature TotalBsmtSF : Fill 0 with 990.0.
# Feature MasVnrArea : Fill None with 0.0.
# Feature Electrical : Fill None with SBrkr.
# Feature 2ndFlrSF : Fill 0 with 0.0.
# Feature LowQualFinSF : Fill 0 with 0.0.
# Feature BsmtFullBath : Fill 0 with 0.0.
# Feature BsmtHalfBath : Fill 0 with 0.0.
# Feature FullBath : Fill 0 with 2.0.
# Feature HalfBath : Fill 0 with 0.0.
# Feature BedroomAbvGr : Fill 0 with 3.0.
# Feature KitchenAbvGr : Fill 0 with 1.0.
# Feature Fireplaces : Fill 0 with 1.0.
# Feature WoodDeckSF : Fill 0 with 0.0.
# Feature OpenPorchSF : Fill 0 with 24.0.
# Feature EnclosedPorch : Fill 0 with 0.0.
# ...

# %%
from sklearn.preprocessing import StandardScaler

# Standardize the predictors
ss = StandardScaler()
X_f_train_s = ss.fit_transform(X_f_train.values)
X_f_test_s = ss.transform(X_f_test.values)
print(X_f_train_s.shape)
print(type(X_f_train_s))
# Out:
# (1221, 132)
# <class 'numpy.ndarray'>

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import SGDRegressor, LinearRegression

# %%
# Set up the gridsearch parameters:
sgd_params = {
    'loss':['squared_loss'],
    'penalty':['l1','l2','elasticnet'],
    'l1_ratio':[.95, .99, 1],
    'alpha':np.logspace(-5,1,25)
}

sgd_reg = SGDRegressor()
sgd_reg_gs = GridSearchCV(sgd_reg, sgd_params, cv=5, verbose=True)

sgd_reg_gs.fit(X_f_train_s, y_train)
# Out:
# Fitting 5 folds for each of 225 candidates, totalling 1125 fits
# C:\Users\mail\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDRegressor'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# C:\Users\mail\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDRegressor'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
# ...

# %%
# list the hyperparameters and score for the best model
print(sgd_reg_gs.best_params_)
print(sgd_reg_gs.best_score_)
sgd_reg_f = sgd_reg_gs.best_estimator_
# Out:
# {'alpha': 0.5623413251903491, 'l1_ratio': 1, 'loss': 'squared_loss', 'penalty': 'l2'}
# 0.7918803654797593

# %%
# list the top 10 features and coefficients of this model
value_coefs = pd.DataFrame({'coef':sgd_reg_f.coef_,
                            'mag':np.abs(sgd_reg_f.coef_),
                            'pred':X_f_train.columns})
value_coefs.sort_values('mag', ascending=False, inplace=True)
value_coefs.iloc[0:10, :]
# Out:
#             coef          mag                  pred
# 118  9261.082819  9261.082819           BsmtQual_Ex
# 5    8897.282371  8897.282371              1stFlrSF
# 52   8422.141371  8422.141371  Neighborhood_NoRidge
# 6    8114.195811  8114.195811              2ndFlrSF
# 13   7865.827726  7865.827726          TotRmsAbvGrd
# 4    7526.264572  7526.264572           TotalBsmtSF
# 73  -6720.643879  6720.643879       Condition2_PosN
# 53   6277.347183  6277.347183  Neighborhood_NridgHt
# 14   6112.840084  6112.840084            Fireplaces
# 9    6096.686738  6096.686738              FullBath

# %%
# evaluate score on test data
sgd_reg_f.score(X_f_test_s, y_test)
# Out:
# 0.8552052824107838

# %%
from sklearn.ensemble import RandomForestRegressor
# Set up the gridsearch parameters:
param_grid = [
    {'n_estimators': [3, 10, 30], 'max_features': [2, 4, 6, 8]},
    {'bootstrap': [False], 'n_estimators': [3, 10], 'max_features': [2, 3, 4]},
]

estimator = RandomForestRegressor()
rf_gs = GridSearchCV(estimator, param_grid, cv=5, verbose=True)

rf_gs.fit(X_f_train, y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [Parallel(n_jobs=1)]: Done  90 out of  90 | elapsed:    2.1s finished
# GridSearchCV(cv=5, error_score='raise',
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid=[{'n_estimators': [3, 10, 30], 'max_features': [2, 4, 6, 8]}, {'bootstrap': [False], 'n_estimators': [3, 10], 'max_features': [2, 3, 4]}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=True)

# %%
rf = rf_gs.best_estimator_
print(rf.score)
# Out:
# <bound method RegressorMixin.score of RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=6, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=30, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False)>

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 2. Determine any value of *changeable* property characteristics unexplained by the *fixed* ones.
#
# ---
#
# Now that you have a model that estimates the price of a house based on its static characteristics, we can move forward with part 2 and 3 of the plan: what are the costs/benefits of quality, condition, and renovations?
#
# There are two specific requirements for these estimates:
# 1. The estimates of effects must be in terms of dollars added or subtracted from the house value.
# 2. The effects must be on the variance in price remaining from the first model.
#
# The residuals from the first model (training and testing) represent the variance in price unexplained by the fixed characteristics. Of that variance in price remaining, how much of it can be explained by the easy-to-change aspects of the property?
#
# ---
#
# **Your goals:**
# 1. Evaluate the effect in dollars of the renovate-able features.
# - How would your company use this second model and its coefficients to determine whether they should buy a property or not? Explain how the company can use the two models you have built to determine if they can make money.
# - Investigate how much of the variance in price remaining is explained by these features.
# - Do you trust your model? Should it be used to evaluate which properties to buy and fix up?

# %%
# Now use the renovatable features for the second model
rf = ['YrSold']
rf.extend(RENOVATABLE_FEATURES)
X_r = house[rf].reindex()

# do the data preprocessing
X_r = helper.transform(X_r)
print(helper)

print(X_r.shape)

PoolQC_Gd
# split into train and test set
X_r_train = X_r[X_r['YrSold'] < 2010].drop(columns=['YrSold','PoolQC_Ex','PoolQC_Gd'])
X_r_test = X_r[X_r['YrSold'] == 2010].drop(columns=['YrSold','PoolQC_Ex','PoolQC_Gd'])

print(X_r_train.shape)

y_r_train = y_train - sgd_reg_f.predict(X_f_train_s)
y_r_test = y_test - sgd_reg_f.predict(X_f_test_s)

(y_test.index.values == X_r_test.index.values).all()
# Out:
# Features to Drop:
# ['Id', 'SalePrice']
#
# Features to Impute:
# Feature LotFrontage : Fill None with 69.0.
# Feature GarageCars : Fill 0 with 2.0.
# Feature GarageArea : Fill 0 with 472.0.
# Feature GarageYrBlt : Fill None with 1978.0.
# Feature BsmtFinSF1 : Fill 0 with 385.0.
# Feature BsmtFinSF2 : Fill 0 with 0.0.
# Feature BsmtUnfSF : Fill 0 with 476.0.
# Feature TotalBsmtSF : Fill 0 with 990.0.
# Feature MasVnrArea : Fill None with 0.0.
# Feature Electrical : Fill None with SBrkr.
# Feature 2ndFlrSF : Fill 0 with 0.0.
# Feature LowQualFinSF : Fill 0 with 0.0.
# Feature BsmtFullBath : Fill 0 with 0.0.
# Feature BsmtHalfBath : Fill 0 with 0.0.
# Feature FullBath : Fill 0 with 2.0.
# Feature HalfBath : Fill 0 with 0.0.
# Feature BedroomAbvGr : Fill 0 with 3.0.
# Feature KitchenAbvGr : Fill 0 with 1.0.
# Feature Fireplaces : Fill 0 with 1.0.
# Feature WoodDeckSF : Fill 0 with 0.0.
# Feature OpenPorchSF : Fill 0 with 24.0.
# Feature EnclosedPorch : Fill 0 with 0.0.
# ...

# %%
# Standardize the predictors
ss = StandardScaler()
X_r_train_s = ss.fit_transform(X_r_train)
#X_r_test_s = ss.transform(X_r_test)

# %%
# Set up the gridsearch parameters:
sgd_params = {
    'loss':['squared_loss'],
    'penalty':['l1','l2','elasticnet'],
    'l1_ratio':[.95, .99, 1],
    'alpha':np.logspace(-5,1,25)
}

sgd_reg = SGDRegressor()
sgd_reg_gs = GridSearchCV(sgd_reg, sgd_params, cv=5, verbose=True)

sgd_reg_gs.fit(X_r_train_s, y_r_train)
# Out:
# Fitting 5 folds for each of 225 candidates, totalling 1125 fits
# C:\Users\mail\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDRegressor'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# C:\Users\mail\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDRegressor'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
# ...

# %%
print(sgd_reg_gs.best_params_)
print(sgd_reg_gs.best_score_)
sgd_reg = sgd_reg_gs.best_estimator_
# Out:
# {'alpha': 1.0, 'l1_ratio': 0.99, 'loss': 'squared_loss', 'penalty': 'l2'}
# 0.08741630140530567

# %%
value_coefs = pd.DataFrame({'coef':sgd_reg.coef_,
                            'mag':np.abs(sgd_reg.coef_),
                            'pred':X_r_train.columns})
value_coefs.sort_values('mag', ascending=False, inplace=True)
value_coefs.iloc[0:10, :]
# Out:
#            coef          mag                 pred
# 87  5426.251736  5426.251736            PoolQC_Ex
# 89 -4069.383279  4069.383279            PoolQC_Gd
# 1   3430.614136  3430.614136          OverallCond
# 0   2920.618931  2920.618931          OverallQual
# 29  2905.828199  2905.828199     RoofMatl_WdShngl
# 22  2730.741059  2730.741059       RoofStyle_Shed
# 50  2642.978474  2642.978474  Exterior2nd_ImStucc
# 23  2013.481517  2013.481517     RoofMatl_CompShg
# 12  1822.659873  1822.659873            3SsnPorch
# 13  1787.482239  1787.482239          ScreenPorch

# %% [markdown]
# <img src="http://imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 3. What property characteristics predict an "abnormal" sale?
#
# ---
#
# The `SaleCondition` feature indicates the circumstances of the house sale. From the data file, we can see that the possibilities are:
#
#        Normal	Normal Sale
#        Abnorml	Abnormal Sale -  trade, foreclosure, short sale
#        AdjLand	Adjoining Land Purchase
#        Alloca	Allocation - two linked properties with separate deeds, typically condo with a garage unit
#        Family	Sale between family members
#        Partial	Home was not completed when last assessed (associated with New Homes)
#
# One of the executives at your company has an "in" with higher-ups at the major regional bank. His friends at the bank have made him a proposal: if he can reliably indicate what features, if any, predict "abnormal" sales (foreclosures, short sales, etc.), then in return the bank will give him first dibs on the pre-auction purchase of those properties (at a dirt-cheap price).
#
# He has tasked you with determining (and adequately validating) which features of a property predict this type of sale.
#
# ---
#
# **Your task:**
# 1. Determine which features predict the `Abnorml` category in the `SaleCondition` feature.
# - Justify your results.
#
# This is a challenging task that tests your ability to perform classification analysis in the face of severe class imbalance. You may find that simply running a classifier on the full dataset to predict the category ends up useless: when there is bad class imbalance classifiers often tend to simply guess the majority class.
#
# It is up to you to determine how you will tackle this problem. I recommend doing some research to find out how others have dealt with the problem in the past. Make sure to justify your solution. Don't worry about it being "the best" solution, but be rigorous.
#
# Be sure to indicate which features are predictive (if any) and whether they are positive or negative predictors of abnormal sales.

# %%
# A:
